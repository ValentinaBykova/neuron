# %% [markdown]
# <a href="https://colab.research.google.com/github/ValentinaBykova/neuron/blob/master/lab1/Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Лабораторна робота №1
# ## студентки КН-31, Бикової Валентини
# ## Тема: Google Colab, NumPy, Pandas ad Matplotlib basics

# %% [markdown]
# # Завдання 2

# %%
import numpy as np
import random as rand

v=4
a=7
l=9

mas = np.array([
                [v, a, l],
                [a, v, l],
                [a, l, v],
                [l, v, a]])# створення масиву

print(np.append(mas, [[2, 3, 4]], axis=0)) #вставка

print(mas.shape[1])#розмірність на другому рівні
print(mas.reshape((3, 4)))#перетворення масиву

print(np.arange(1, 6, 0.5))#створення масиву від до з кроком

print(rand.random())#випадкове число від 0 до 1
# Out:
# [[4 7 9]
#  [7 4 9]
#  [7 9 4]
#  [9 4 7]
#  [2 3 4]]
# 3
# [[4 7 9 7]
#  [4 9 7 9]
#  [4 9 4 7]]
# [1.  1.5 2.  2.5 3.  3.5 4.  4.5 5.  5.5]
# 0.7994889614535501

# %% [markdown]
# # Завдання 3

# %%
import numpy as np
import pandas as pd

v=4
a=7
l=9

data = pd.DataFrame(np.array([[v, a, l],
                [a, v, l],
                [a, l, v],
                [l, v, a]]),
                columns=['v', 'a', 'l'])

print(data)#табличні дані

print(data.head(-1))#повернути деяку кількість рядків

print(data.describe())#описова статистика

print(data.iloc[:6, :1])#індексація за групою рядків

print(data.loc[1:6, 'v'])#індексація окремого рядка

print(data.count())#кількість даних

print(data.sort_index())#сортування за індексом
# Out:
#    v  a  l
# 0  4  7  9
# 1  7  4  9
# 2  7  9  4
# 3  9  4  7
#    v  a  l
# 0  4  7  9
# 1  7  4  9
# 2  7  9  4
#               v        a         l
# count  4.000000  4.00000  4.000000
# mean   6.750000  6.00000  7.250000
# std    2.061553  2.44949  2.362908
# min    4.000000  4.00000  4.000000
# 25%    6.250000  4.00000  6.250000
# 50%    7.000000  5.50000  8.000000
# 75%    7.500000  7.50000  9.000000
# max    9.000000  9.00000  9.000000
#    v
# 0  4
# 1  7
# 2  7
# 3  9
# 1    7
# 2    7
# 3    9
# Name: v, dtype: int64
# v    4
# a    4
# l    4
# dtype: int64
#    v  a  l
# 0  4  7  9
# 1  7  4  9
# 2  7  9  4
# 3  9  4  7

# %% [markdown]
# # Завдання 4

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error

#make data
xpoints = np.array([-9, -7, -4, 0, 4, 7, 9])
ypoints = np.array([9.9, 5, 2.2, 0, 2.1, 5.2, 10.0])

plt.plot(xpoints, ypoints)
plt.show()

print(mean_absolute_error(xpoints, ypoints))#
print(mean_squared_error(xpoints, ypoints))#

import csv

FILENAME = "data.csv"

with open(FILENAME, "w", newline="") as file:
  writer = csv.writer(file)
  writer.writerow(["Name", "Value"])
  writer.writerows([
                    ["x", xpoints],
                    ["y", ypoints],
                    ["mae", mean_absolute_error(xpoints, ypoints)],
                    ["mse", mean_squared_error(xpoints, ypoints)]
  ])
# Out:
# 5.971428571428571
# 78.21428571428571

# %% [markdown]
# # Завдання 5(з інтернету)

# %%
# !wget http://vis-www.cs.umass.edu/lfw/lfw-a.zip

from zipfile import ZipFile
archive = 'lfw-a.zip'
zip_file = ZipFile(archive)
[text_file.filename for text_file in zip_file.infolist()]
# Out:
# --2022-02-20 18:35:09--  http://vis-www.cs.umass.edu/lfw/lfw-a.zip
# Resolving vis-www.cs.umass.edu (vis-www.cs.umass.edu)... 128.119.244.95
# Connecting to vis-www.cs.umass.edu (vis-www.cs.umass.edu)|128.119.244.95|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15167852 (14M) [application/zip]
# Saving to: ‘lfw-a.zip.1’
#
# lfw-a.zip.1         100%[===================>]  14.46M  32.2MB/s    in 0.4s
#
# 2022-02-20 18:35:09 (32.2 MB/s) - ‘lfw-a.zip.1’ saved [15167852/15167852]
# ['lfw/Aaron_Eckhart/',
#  'lfw/Aaron_Eckhart/Aaron_Eckhart_0001.jpg',
#  'lfw/Aaron_Guiel/',
#  'lfw/Aaron_Guiel/Aaron_Guiel_0001.jpg',
#  'lfw/Aaron_Patterson/',
#  'lfw/Aaron_Patterson/Aaron_Patterson_0001.jpg',
#  'lfw/Aaron_Peirsol/',
#  'lfw/Aaron_Peirsol/Aaron_Peirsol_0001.jpg',
#  'lfw/Aaron_Peirsol/Aaron_Peirsol_0002.jpg',
#  'lfw/Aaron_Peirsol/Aaron_Peirsol_0003.jpg',
#  'lfw/Aaron_Peirsol/Aaron_Peirsol_0004.jpg',
#  'lfw/Aaron_Pena/',
# ...

# %% [markdown]
# # Завдання 5(з компʼютера)

# %%
from google.colab import files

# %%
files.upload()
# Out:
#      <input type="file" id="files-3909bf80-0b78-444e-839e-6fc2d0aa5afd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3909bf80-0b78-444e-839e-6fc2d0aa5afd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-18-63b259460c61> in <module>()
# ----> 1 files.upload()
#
# /usr/local/lib/python3.7/dist-packages/google/colab/files.py in upload()
#      69     result = _output.eval_js(
#      70         'google.colab._files._uploadFilesContinue("{output_id}")'.format(
# ---> 71             output_id=output_id))
#      72     if result['action'] != 'append':
# ...

# %%
from IPython.display import Image
Image('rock.jpg')

# %% [markdown]
# # Завдання 5(з гугл-диска)

# %%
from google.colab import drive

drive.mount('/content/gdrive', force_remount=True)

from IPython.display import Image
Image('/content/gdrive/MyDrive/rock.png')
# Out:
# Mounted at /content/gdrive
